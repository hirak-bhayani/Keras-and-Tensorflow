# %% [markdown]
# # Introduction to TensorFlow Data Validation
#
#
# ## Learning objectives
#
# 1. Review TFDV methods.
# 2. Generate statistics.
# 3. Visualize statistics.
# 4. Infer a schema.
# 5. Update a schema.
#
#
#
# ## Introduction
# This lab is an introduction to TensorFlow Data Validation (TFDV), a key component of TensorFlow Extended.  This lab serves as a foundation for understanding the features of TFDV and how it can help you understand, validate, and monitor your data.
#
# TFDV can be used for generating schemas and statistics about the distribution of every feature in the dataset. Such information is useful for comparing multiple datasets (e.g. training vs inference datasets) and reporting:
#
# Statistical differences in the features distribution
# TFDV also offers visualization capabilities for comparing datasets based on the Google PAIR Facets project.
#
# Each learning objective will correspond to a __#TODO__ in this student lab notebook -- try to complete this notebook first and then review the [solution notebook](../solutions/tfdv_basic_spending.ipynb).

# %% [markdown]
# ### Import Libraries

# %%
# !pip install pyarrow
# !pip install numpy
# !pip install tensorflow-data-validation --user
# Out:
# Requirement already satisfied: pyarrow in /home/jupyter/.local/lib/python3.10/site-packages (10.0.1)
# Requirement already satisfied: numpy>=1.16.6 in /opt/conda/lib/python3.10/site-packages (from pyarrow) (1.26.4)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.26.4)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: tensorflow-data-validation in /home/jupyter/.local/lib/python3.10/site-packages (1.16.1)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation) (1.4.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow-data-validation) (1.5.2)
# Requirement already satisfied: numpy>=1.22.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow-data-validation) (1.26.4)
# Requirement already satisfied: pandas<2,>=1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation) (1.5.3)
# Requirement already satisfied: pyarrow<11,>=10 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation) (10.0.1)
# Requirement already satisfied: pyfarmhash<0.4,>=0.2.2 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation) (0.3.2)
# Requirement already satisfied: six<2,>=1.12 in /opt/conda/lib/python3.10/site-packages (from tensorflow-data-validation) (1.17.0)
# Requirement already satisfied: tensorflow<2.17,>=2.16 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation) (2.16.2)
# Requirement already satisfied: tensorflow-metadata<1.17,>=1.16.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation) (1.16.1)
# Requirement already satisfied: tfx-bsl<1.17,>=1.16.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation) (1.16.1)
# Requirement already satisfied: apache-beam<3,>=2.47 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.69.0)
# Requirement already satisfied: protobuf<5,>=3.20.3 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation) (3.20.3)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.7)
# Requirement already satisfied: cryptography<48.0.0,>=39.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (46.0.2)
# Requirement already satisfied: orjson<4,>=3.9.7 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.11.4)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.12.1)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.20)
# Requirement already satisfied: grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.65.5)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.22.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (4.25.1)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.4.2)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.7.1)
# Requirement already satisfied: packaging>=22.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (25.0)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (4.15.3)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.26.1)
# Requirement already satisfied: pydot<2,>=1.2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.3 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2025.2)
# Requirement already satisfied: redis<6,>=5.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (5.3.1)
# Requirement already satisfied: regex>=2020.6.8 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2025.10.23)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.32.5)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (4.15.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=3.12 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (6.0.3)
# Requirement already satisfied: beartype<0.22.0,>=0.21.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.21.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.7)
# Requirement already satisfied: cachetools<7,>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (6.2.0)
# Requirement already satisfied: google-api-core<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.26.0)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.5.31)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.41.1)
# Requirement already satisfied: google-auth-httplib2<0.3.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.2.0)
# Requirement already satisfied: google-cloud-datastore<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.21.0)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.33.0)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.12.0)
# Requirement already satisfied: google-cloud-storage<3,>=2.18.2 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery<4,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.38.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3,>=2.6.3 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.33.1)
# Requirement already satisfied: google-cloud-core<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.4.3)
# Requirement already satisfied: google-cloud-bigtable<3,>=2.19.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.34.0)
# Requirement already satisfied: google-cloud-spanner<4,>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.59.0)
# Requirement already satisfied: google-cloud-dlp<4,>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.33.0)
# Requirement already satisfied: google-cloud-language<3,>=2.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.17.2)
# Requirement already satisfied: google-cloud-secret-manager<3,>=2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.25.0)
# Requirement already satisfied: google-cloud-videointelligence<3,>=2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.17.0)
# Requirement already satisfied: google-cloud-vision<4,>=2 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.11.0)
# Requirement already satisfied: google-cloud-recommendations-ai<0.11.0,>=0.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.10.18)
# Requirement already satisfied: google-cloud-aiplatform<2.0,>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.120.0)
# Requirement already satisfied: cloud-sql-python-connector<2.0.0,>=1.18.2 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.18.5)
# Requirement already satisfied: python-tds>=1.16.1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.17.1)
# Requirement already satisfied: pg8000>=1.31.1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.31.5)
# Requirement already satisfied: PyMySQL>=1.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.1.2)
# Requirement already satisfied: keyrings.google-artifactregistry-auth in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.1.2)
# Requirement already satisfied: aiofiles in /opt/conda/lib/python3.10/site-packages (from cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (22.1.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.13.0)
# Requirement already satisfied: dnspython>=2.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.8.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from cryptography<48.0.0,>=39.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3,>=2.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.70.0)
# Requirement already satisfied: oauth2client>=1.4.12 in /opt/conda/lib/python3.10/site-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (4.1.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (4.9.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.1.2)
# Requirement already satisfied: google-genai<2.0.0,>=1.37.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.42.0)
# Requirement already satisfied: pydantic<3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.12.0)
# Requirement already satisfied: docstring_parser<1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.17.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/jupyter/.local/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.49.0rc1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.7.1)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.37.0)
# Requirement already satisfied: overrides<8.0.0,>=6.0.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (7.7.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /home/jupyter/.local/lib/python3.10/site-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.15.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (4.11.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.3.1)
# Requirement already satisfied: docopt in /home/jupyter/.local/lib/python3.10/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.6.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.10/site-packages (from httplib2<0.23.0,>=0.8->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.2.5)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.27.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.4.2)
# Requirement already satisfied: PyJWT>=2.9.0 in /home/jupyter/.local/lib/python3.10/site-packages (from redis<6,>=5.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.10.1)
# Requirement already satisfied: async-timeout>=4.0.3 in /opt/conda/lib/python3.10/site-packages (from redis<6,>=5.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (5.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.4->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.4->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.6.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (3.4.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (80.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (1.17.3)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (3.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tensorflow-data-validation) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tensorflow-data-validation) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tensorflow-data-validation) (3.1.3)
# Requirement already satisfied: google-api-python-client<2,>=1.7.11 in /home/jupyter/.local/lib/python3.10/site-packages (from tfx-bsl<1.17,>=1.16.0->tensorflow-data-validation) (1.12.11)
# Requirement already satisfied: tensorflow-serving-api<3,>=2.13.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tfx-bsl<1.17,>=1.16.0->tensorflow-data-validation) (2.16.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<1.17,>=1.16.0->tensorflow-data-validation) (3.0.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<2.17,>=2.16->tensorflow-data-validation) (0.45.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography<48.0.0,>=39.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.22)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow-data-validation) (13.9.4)
# Requirement already satisfied: namex in /home/jupyter/.local/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow-data-validation) (0.1.0)
# Requirement already satisfied: optree in /home/jupyter/.local/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow-data-validation) (0.17.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.58b0)
# Requirement already satisfied: scramp>=1.4.5 in /home/jupyter/.local/lib/python3.10/site-packages (from pg8000>=1.31.1->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.4.6)
# Requirement already satisfied: asn1crypto>=1.5.1 in /home/jupyter/.local/lib/python3.10/site-packages (from scramp>=1.4.5->pg8000>=1.31.1->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.5.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tensorflow-data-validation) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.22.0)
# Requirement already satisfied: keyring in /opt/conda/lib/python3.10/site-packages (from keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (25.6.0)
# Requirement already satisfied: pluggy in /opt/conda/lib/python3.10/site-packages (from keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.6.0)
# Requirement already satisfied: SecretStorage>=3.2 in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.4.0)
# Requirement already satisfied: jeepney>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.9.0)
# Requirement already satisfied: jaraco.classes in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.4.0)
# Requirement already satisfied: jaraco.functools in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (4.3.0)
# Requirement already satisfied: jaraco.context in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (6.0.1)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.10/site-packages (from jaraco.classes->keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (10.8.0)
# Requirement already satisfied: backports.tarfile in /opt/conda/lib/python3.10/site-packages (from jaraco.context->keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow-data-validation) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow-data-validation) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow-data-validation) (0.1.2)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# **Restart the kernel (Kernel > Restart kernel > Restart).**
#
# **Re-run the above cell and proceed further.**
#
# **Note: Please ignore any incompatibility warnings and errors.**

# %%
# !pip install dill
# !pip install tfx-bsl
# Out:
# Collecting dill
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Installing collected packages: dill
# Successfully installed dill-0.4.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: tfx-bsl in /home/jupyter/.local/lib/python3.10/site-packages (1.16.1)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /home/jupyter/.local/lib/python3.10/site-packages (from tfx-bsl) (1.4.0)
# Requirement already satisfied: google-api-python-client<2,>=1.7.11 in /home/jupyter/.local/lib/python3.10/site-packages (from tfx-bsl) (1.12.11)
# Requirement already satisfied: numpy>=1.22.0 in /opt/conda/lib/python3.10/site-packages (from tfx-bsl) (1.26.4)
# Requirement already satisfied: pandas<2,>=1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tfx-bsl) (1.5.3)
# Requirement already satisfied: pyarrow<11,>=10 in /home/jupyter/.local/lib/python3.10/site-packages (from tfx-bsl) (10.0.1)
# Requirement already satisfied: tensorflow<2.17,>=2.16 in /home/jupyter/.local/lib/python3.10/site-packages (from tfx-bsl) (2.16.2)
# Requirement already satisfied: tensorflow-metadata<1.17.0,>=1.16.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tfx-bsl) (1.16.1)
# Requirement already satisfied: tensorflow-serving-api<3,>=2.13.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tfx-bsl) (2.16.1)
# Requirement already satisfied: apache-beam<3,>=2.47 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.69.0)
# Requirement already satisfied: protobuf<5,>=3.20.3 in /home/jupyter/.local/lib/python3.10/site-packages (from tfx-bsl) (3.20.3)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.7)
# Requirement already satisfied: cryptography<48.0.0,>=39.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (46.0.2)
# Requirement already satisfied: orjson<4,>=3.9.7 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.11.4)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.12.1)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.20)
# Requirement already satisfied: grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.65.5)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.22.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (4.25.1)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.4.2)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.7.1)
# Requirement already satisfied: packaging>=22.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (25.0)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (4.15.3)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.26.1)
# Requirement already satisfied: pydot<2,>=1.2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.3 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2025.2)
# Requirement already satisfied: redis<6,>=5.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (5.3.1)
# Requirement already satisfied: regex>=2020.6.8 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2025.10.23)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.32.5)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (4.15.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=3.12 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (6.0.3)
# Requirement already satisfied: beartype<0.22.0,>=0.21.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.21.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.7)
# Requirement already satisfied: cachetools<7,>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (6.2.0)
# Requirement already satisfied: google-api-core<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.26.0)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.5.31)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.41.1)
# Requirement already satisfied: google-auth-httplib2<0.3.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.2.0)
# Requirement already satisfied: google-cloud-datastore<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.21.0)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.33.0)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.12.0)
# Requirement already satisfied: google-cloud-storage<3,>=2.18.2 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery<4,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.38.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3,>=2.6.3 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.33.1)
# Requirement already satisfied: google-cloud-core<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.4.3)
# Requirement already satisfied: google-cloud-bigtable<3,>=2.19.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.34.0)
# Requirement already satisfied: google-cloud-spanner<4,>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.59.0)
# Requirement already satisfied: google-cloud-dlp<4,>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.33.0)
# Requirement already satisfied: google-cloud-language<3,>=2.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.17.2)
# Requirement already satisfied: google-cloud-secret-manager<3,>=2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.25.0)
# Requirement already satisfied: google-cloud-videointelligence<3,>=2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.17.0)
# Requirement already satisfied: google-cloud-vision<4,>=2 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.11.0)
# Requirement already satisfied: google-cloud-recommendations-ai<0.11.0,>=0.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.10.18)
# Requirement already satisfied: google-cloud-aiplatform<2.0,>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.120.0)
# Requirement already satisfied: cloud-sql-python-connector<2.0.0,>=1.18.2 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.18.5)
# Requirement already satisfied: python-tds>=1.16.1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.17.1)
# Requirement already satisfied: pg8000>=1.31.1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.31.5)
# Requirement already satisfied: PyMySQL>=1.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.1.2)
# Requirement already satisfied: keyrings.google-artifactregistry-auth in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.1.2)
# Requirement already satisfied: aiofiles in /opt/conda/lib/python3.10/site-packages (from cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (22.1.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.13.0)
# Requirement already satisfied: dnspython>=2.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.8.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from cryptography<48.0.0,>=39.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3,>=2.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.70.0)
# Requirement already satisfied: six<2dev,>=1.13.0 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl) (1.17.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl) (3.0.1)
# Requirement already satisfied: oauth2client>=1.4.12 in /opt/conda/lib/python3.10/site-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (4.1.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (4.9.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.1.2)
# Requirement already satisfied: google-genai<2.0.0,>=1.37.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.42.0)
# Requirement already satisfied: pydantic<3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.12.0)
# Requirement already satisfied: docstring_parser<1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.17.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/jupyter/.local/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.49.0rc1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.7.1)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.37.0)
# Requirement already satisfied: overrides<8.0.0,>=6.0.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (7.7.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /home/jupyter/.local/lib/python3.10/site-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.15.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (4.11.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.3.1)
# Requirement already satisfied: docopt in /home/jupyter/.local/lib/python3.10/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.6.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.10/site-packages (from httplib2<0.23.0,>=0.8->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.2.5)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.27.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.4.2)
# Requirement already satisfied: PyJWT>=2.9.0 in /home/jupyter/.local/lib/python3.10/site-packages (from redis<6,>=5.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.10.1)
# Requirement already satisfied: async-timeout>=4.0.3 in /opt/conda/lib/python3.10/site-packages (from redis<6,>=5.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (5.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.4->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.4->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.6.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (3.4.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (80.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (1.17.3)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (3.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tfx-bsl) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tfx-bsl) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tfx-bsl) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tfx-bsl) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<2.17,>=2.16->tfx-bsl) (0.45.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography<48.0.0,>=39.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.22)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tfx-bsl) (13.9.4)
# Requirement already satisfied: namex in /home/jupyter/.local/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tfx-bsl) (0.1.0)
# Requirement already satisfied: optree in /home/jupyter/.local/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tfx-bsl) (0.17.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.58b0)
# Requirement already satisfied: scramp>=1.4.5 in /home/jupyter/.local/lib/python3.10/site-packages (from pg8000>=1.31.1->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.4.6)
# Requirement already satisfied: asn1crypto>=1.5.1 in /home/jupyter/.local/lib/python3.10/site-packages (from scramp>=1.4.5->pg8000>=1.31.1->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.5.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tfx-bsl) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.22.0)
# Requirement already satisfied: keyring in /opt/conda/lib/python3.10/site-packages (from keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (25.6.0)
# Requirement already satisfied: pluggy in /opt/conda/lib/python3.10/site-packages (from keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.6.0)
# Requirement already satisfied: SecretStorage>=3.2 in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.4.0)
# Requirement already satisfied: jeepney>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (0.9.0)
# Requirement already satisfied: jaraco.classes in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (3.4.0)
# Requirement already satisfied: jaraco.functools in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (4.3.0)
# Requirement already satisfied: jaraco.context in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (6.0.1)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.10/site-packages (from jaraco.classes->keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (10.8.0)
# Requirement already satisfied: backports.tarfile in /opt/conda/lib/python3.10/site-packages (from jaraco.context->keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tfx-bsl) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tfx-bsl) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tfx-bsl) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tfx-bsl) (0.1.2)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --upgrade tensorflow-data-validation[tfx_bsl,visualization]
# Out:
# Requirement already satisfied: tensorflow-data-validation[tfx_bsl,visualization] in /home/jupyter/.local/lib/python3.10/site-packages (1.16.1)
# WARNING: tensorflow-data-validation 1.16.1 does not provide the extra 'tfx-bsl'
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation[tfx_bsl,visualization]) (1.4.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow-data-validation[tfx_bsl,visualization]) (1.5.2)
# Requirement already satisfied: numpy>=1.22.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow-data-validation[tfx_bsl,visualization]) (1.26.4)
# Requirement already satisfied: pandas<2,>=1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation[tfx_bsl,visualization]) (1.5.3)
# Requirement already satisfied: pyarrow<11,>=10 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation[tfx_bsl,visualization]) (10.0.1)
# Requirement already satisfied: pyfarmhash<0.4,>=0.2.2 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation[tfx_bsl,visualization]) (0.3.2)
# Requirement already satisfied: six<2,>=1.12 in /opt/conda/lib/python3.10/site-packages (from tensorflow-data-validation[tfx_bsl,visualization]) (1.17.0)
# Requirement already satisfied: tensorflow<2.17,>=2.16 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation[tfx_bsl,visualization]) (2.16.2)
# Requirement already satisfied: tensorflow-metadata<1.17,>=1.16.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation[tfx_bsl,visualization]) (1.16.1)
# Requirement already satisfied: tfx-bsl<1.17,>=1.16.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation[tfx_bsl,visualization]) (1.16.1)
# Requirement already satisfied: apache-beam<3,>=2.47 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.69.0)
# Requirement already satisfied: protobuf<5,>=3.20.3 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow-data-validation[tfx_bsl,visualization]) (3.20.3)
# Collecting ipython<8,>=7 (from tensorflow-data-validation[tfx_bsl,visualization])
#   Downloading ipython-7.34.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.7)
# Requirement already satisfied: cryptography<48.0.0,>=39.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (46.0.2)
# Requirement already satisfied: orjson<4,>=3.9.7 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.11.4)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.12.1)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.20)
# Requirement already satisfied: grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.65.5)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.22.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (4.25.1)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.4.2)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.7.1)
# Requirement already satisfied: packaging>=22.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (25.0)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (4.15.3)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.26.1)
# Requirement already satisfied: pydot<2,>=1.2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.3 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2025.2)
# Requirement already satisfied: redis<6,>=5.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (5.3.1)
# Requirement already satisfied: regex>=2020.6.8 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2025.10.23)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.32.5)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (4.15.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=3.12 in /opt/conda/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (6.0.3)
# Requirement already satisfied: beartype<0.22.0,>=0.21.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.21.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.7)
# Requirement already satisfied: cachetools<7,>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (6.2.0)
# Requirement already satisfied: google-api-core<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.26.0)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.5.31)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.41.1)
# Requirement already satisfied: google-auth-httplib2<0.3.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.2.0)
# Requirement already satisfied: google-cloud-datastore<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.21.0)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.33.0)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.12.0)
# Requirement already satisfied: google-cloud-storage<3,>=2.18.2 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery<4,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.38.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3,>=2.6.3 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.33.1)
# Requirement already satisfied: google-cloud-core<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.4.3)
# Requirement already satisfied: google-cloud-bigtable<3,>=2.19.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.34.0)
# Requirement already satisfied: google-cloud-spanner<4,>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.59.0)
# Requirement already satisfied: google-cloud-dlp<4,>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.33.0)
# Requirement already satisfied: google-cloud-language<3,>=2.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.17.2)
# Requirement already satisfied: google-cloud-secret-manager<3,>=2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.25.0)
# Requirement already satisfied: google-cloud-videointelligence<3,>=2.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.17.0)
# Requirement already satisfied: google-cloud-vision<4,>=2 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.11.0)
# Requirement already satisfied: google-cloud-recommendations-ai<0.11.0,>=0.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.10.18)
# Requirement already satisfied: google-cloud-aiplatform<2.0,>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.120.0)
# Requirement already satisfied: cloud-sql-python-connector<2.0.0,>=1.18.2 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.18.5)
# Requirement already satisfied: python-tds>=1.16.1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.17.1)
# Requirement already satisfied: pg8000>=1.31.1 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.31.5)
# Requirement already satisfied: PyMySQL>=1.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.1.2)
# Requirement already satisfied: keyrings.google-artifactregistry-auth in /opt/conda/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.1.2)
# Requirement already satisfied: aiofiles in /opt/conda/lib/python3.10/site-packages (from cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (22.1.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.13.0)
# Requirement already satisfied: dnspython>=2.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.8.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from cryptography<48.0.0,>=39.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3,>=2.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.70.0)
# Requirement already satisfied: oauth2client>=1.4.12 in /opt/conda/lib/python3.10/site-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (4.1.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (4.9.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.1.2)
# Requirement already satisfied: google-genai<2.0.0,>=1.37.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.42.0)
# Requirement already satisfied: pydantic<3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.12.0)
# Requirement already satisfied: docstring_parser<1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.17.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/jupyter/.local/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.49.0rc1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.7.1)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.37.0)
# Requirement already satisfied: overrides<8.0.0,>=6.0.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (7.7.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /home/jupyter/.local/lib/python3.10/site-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.15.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (4.11.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.3.1)
# Requirement already satisfied: docopt in /home/jupyter/.local/lib/python3.10/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.6.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.10/site-packages (from httplib2<0.23.0,>=0.8->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.2.5)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.16.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.10/site-packages (from ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization]) (80.9.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization]) (0.19.2)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization]) (5.2.1)
# Collecting pickleshare (from ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization])
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.10/site-packages (from ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization]) (5.14.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization]) (3.0.52)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.10/site-packages (from ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization]) (2.19.2)
# Collecting backcall (from ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization])
#   Downloading backcall-0.2.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization]) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.27.1)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization]) (0.2.14)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.4.2)
# Requirement already satisfied: PyJWT>=2.9.0 in /home/jupyter/.local/lib/python3.10/site-packages (from redis<6,>=5.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.10.1)
# Requirement already satisfied: async-timeout>=4.0.3 in /opt/conda/lib/python3.10/site-packages (from redis<6,>=5.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (5.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.4->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.4->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.6.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (3.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (1.17.3)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (3.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/jupyter/.local/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (3.1.3)
# Requirement already satisfied: google-api-python-client<2,>=1.7.11 in /home/jupyter/.local/lib/python3.10/site-packages (from tfx-bsl<1.17,>=1.16.0->tensorflow-data-validation[tfx_bsl,visualization]) (1.12.11)
# Requirement already satisfied: tensorflow-serving-api<3,>=2.13.0 in /home/jupyter/.local/lib/python3.10/site-packages (from tfx-bsl<1.17,>=1.16.0->tensorflow-data-validation[tfx_bsl,visualization]) (2.16.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /home/jupyter/.local/lib/python3.10/site-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<1.17,>=1.16.0->tensorflow-data-validation[tfx_bsl,visualization]) (3.0.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (0.45.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography<48.0.0,>=39.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization]) (0.8.5)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (13.9.4)
# Requirement already satisfied: namex in /home/jupyter/.local/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (0.1.0)
# Requirement already satisfied: optree in /home/jupyter/.local/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (0.17.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.58b0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython<8,>=7->tensorflow-data-validation[tfx_bsl,visualization]) (0.7.0)
# Requirement already satisfied: scramp>=1.4.5 in /home/jupyter/.local/lib/python3.10/site-packages (from pg8000>=1.31.1->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.4.6)
# Requirement already satisfied: asn1crypto>=1.5.1 in /home/jupyter/.local/lib/python3.10/site-packages (from scramp>=1.4.5->pg8000>=1.31.1->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.5.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.22.0)
# Requirement already satisfied: keyring in /opt/conda/lib/python3.10/site-packages (from keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (25.6.0)
# Requirement already satisfied: pluggy in /opt/conda/lib/python3.10/site-packages (from keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.6.0)
# Requirement already satisfied: SecretStorage>=3.2 in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.4.0)
# Requirement already satisfied: jeepney>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (0.9.0)
# Requirement already satisfied: jaraco.classes in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (3.4.0)
# Requirement already satisfied: jaraco.functools in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (4.3.0)
# Requirement already satisfied: jaraco.context in /opt/conda/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (6.0.1)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.10/site-packages (from jaraco.classes->keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (10.8.0)
# Requirement already satisfied: backports.tarfile in /opt/conda/lib/python3.10/site-packages (from jaraco.context->keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation[tfx_bsl,visualization]) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow-data-validation[tfx_bsl,visualization]) (0.1.2)
# Downloading ipython-7.34.0-py3-none-any.whl (793 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.8/793.8 kB 34.7 MB/s  0:00:00
# Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: pickleshare, backcall, ipython
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.37.0
#     Uninstalling ipython-8.37.0:
#       Successfully uninstalled ipython-8.37.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [ipython]m2/3 [ipython]
# Successfully installed backcall-0.2.0 ipython-7.34.0 pickleshare-0.7.5
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import tensorflow_data_validation as tfdv
import sys
import warnings
warnings.filterwarnings('ignore')

print('Installing TensorFlow Data Validation')
# !pip install -q tensorflow_data_validation[visualization]

print('TFDV version: {}'.format(tfdv.version.__version__))
# Confirm that we're using Python 3
assert sys.version_info.major == 3, 'Oops, not running Python 3. Use Runtime > Change runtime type'
# Out:
# Installing TensorFlow Data Validation
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# TFDV version: 1.16.1

# %% [markdown]
# ###  Load the Consumer Spending Dataset
#
# We will download our dataset from Google Cloud Storage. The columns in the dataset are:
#
# * 'Graduated': Whether or not the person is a college graduate
# * 'Work Experience': The number of years in the workforce
# * 'Family Size': The size of the family unit
# * 'Spending Score': The spending score for consumer spending

# %%
# TODO
score_train = pd.read_csv('data/score_train.csv')
score_train.head()
# Out:
#   Graduated     Profession  Work_Experience  Family_Size Spending_Score
# 0        No     Healthcare              1.0          4.0            Low
# 1       Yes       Engineer              NaN          3.0        Average
# 2       Yes       Engineer              1.0          1.0            Low
# 3       Yes         Lawyer              0.0          2.0           High
# 4       Yes  Entertainment              NaN          6.0           High

# %%
# TODO
score_test = pd.read_csv('data/score_test.csv')
score_test.head()
# Out:
#   Graduated     Profession  Work_Experience  Family_Size Spending_Score
# 0        No         Doctor              0.0          5.0        Average
# 1       Yes  Entertainment              1.0          4.0        Average
# 2        No         Lawyer              0.0          5.0            Low
# 3       Yes      Executive              1.0          5.0           High
# 4       Yes         Artist              1.0          2.0        Average

# %%
score_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Graduated        3964 non-null   object
#  1   Profession       3944 non-null   object
#  2   Work_Experience  3589 non-null   float64
#  3   Family_Size      3831 non-null   float64
#  4   Spending_Score   4000 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 156.4+ KB

# %% [markdown]
# #### Review the methods present in TFDV

# %%
# check methods present in tfdv
# TODO
[methods for methods in dir(tfdv)]
# Out:
# ['CombinerStatsGenerator',
#  'CrossFeatureView',
#  'DatasetListView',
#  'DatasetView',
#  'DetectFeatureSkew',
#  'FeaturePath',
#  'FeatureView',
#  'GenerateStatistics',
#  'MergeDatasetFeatureStatisticsList',
#  'StatsOptions',
#  'TransformStatsGenerator',
#  'WriteStatisticsToBinaryFile',
#  'WriteStatisticsToRecordsAndBinaryFile',
#  'WriteStatisticsToTFRecord',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'anomalies',
#  'coders',
#  'compare_slices',
#  'default_sharded_output_suffix',
#  'default_sharded_output_supported',
#  'display_anomalies',
#  'display_schema',
#  'experimental_get_feature_value_slicer',
#  'generate_dummy_schema_with_paths',
#  'generate_statistics_from_csv',
#  'generate_statistics_from_dataframe',
#  'generate_statistics_from_tfrecord',
#  'get_confusion_count_dataframes',
#  'get_domain',
#  'get_feature',
#  'get_feature_stats',
#  'get_match_stats_dataframe',
#  'get_skew_result_dataframe',
#  'get_slice_stats',
#  'get_statistics_html',
#  'infer_schema',
#  'load_anomalies_text',
#  'load_schema_text',
#  'load_sharded_statistics',
#  'load_statistics',
#  'load_stats_binary',
#  'load_stats_text',
#  'pywrap',
#  'set_domain',
#  'skew',
#  'update_schema',
#  'validate_corresponding_slices',
#  'validate_examples_in_csv',
#  'validate_examples_in_tfrecord',
#  'validate_statistics',
#  'version',
#  'visualize_statistics',
#  'write_anomalies_text',
#  'write_schema_text',
#  'write_stats_text']

# %% [markdown]
# ### Describing data with TFDV
# The usual workflow when using TFDV during training is as follows:
#
#
# 1.   Generate statistics for the data
# 2.   Use those statistics to generate a schema for each feature
# 3.   Visualize the schema and statistics and manually inspect them
# 4.   Update the schema if needed

# %% [markdown]
# ### Compute and visualize statistics
#
# First we'll use [`tfdv.generate_statistics_from_csv`](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/generate_statistics_from_csv) to compute statistics for our training data. (ignore the snappy warnings)
#
# TFDV can compute descriptive [statistics](https://github.com/tensorflow/metadata/blob/v0.6.0/tensorflow_metadata/proto/v0/statistics.proto) that provide a quick overview of the data in terms of the features that are present and the shapes of their value distributions.
#
# Internally, TFDV uses [Apache Beam](https://beam.apache.org/)'s data-parallel processing framework to scale the computation of statistics over large datasets. For applications that wish to integrate deeper with TFDV (e.g., attach statistics generation at the end of a data-generation pipeline), the API also exposes a Beam PTransform for statistics generation.
#
# **NOTE:  Compute statistics**
# * [tfdv.generate_statistics_from_csv](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/generate_statistics_from_csv)
# * [tfdv.generate_statistics_from_dataframe](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/generate_statistics_from_dataframe)
# * [tfdv.generate_statistics_from_tfrecord](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/generate_statistics_from_tfrecord)

# %% [markdown]
# #### Generate Statistics from a Pandas DataFrame

# %%
# Compute data statistics for the input pandas DataFrame.
# TODO
stats = tfdv.generate_statistics_from_dataframe(dataframe=score_train)

# %% [markdown]
# Now let's use [`tfdv.visualize_statistics`](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/visualize_statistics), which uses [Facets](https://pair-code.github.io/facets/) to create a succinct visualization of our training data:
#
# * Notice that numeric features and categorical features are visualized separately, and that charts are displayed showing the distributions for each feature.
# * Notice that features with missing or zero values display a percentage in red as a visual indicator that there may be issues with examples in those features.  The percentage is the percentage of examples that have missing or zero values for that feature.
# * Notice that there are no examples with values for `pickup_census_tract`.  This is an opportunity for dimensionality reduction!
# * Try clicking "expand" above the charts to change the display
# * Try hovering over bars in the charts to display bucket ranges and counts
# * Try switching between the log and linear scales, and notice how the log scale reveals much more detail about the `payment_type` categorical feature
# * Try selecting "quantiles" from the "Chart to show" menu, and hover over the markers to show the quantile percentages

# %%
# Visualize the input statistics using Facets.
# TODO
tfdv.visualize_statistics(stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# #### TFDV generates different types of statistics based on the type of features.
#
# **For numerical features, TFDV computes for every feature:**
# * Count of records
# * Number of missing (i.e. null values)
# * Histogram of values
# * Mean and standard deviation
# * Minimum and maximum values
# * Percentage of zero values
#
# **For categorical features, TFDV provides:**
# * Count of values
# * Percentage of missing values
# * Number of unique values
# * Average string length
# * Count for each label and its rank

# %% [markdown]
# ### Let's compare the score_train and the score_test datasets

# %%
train_stats = tfdv.generate_statistics_from_dataframe(dataframe=score_train)
test_stats = tfdv.generate_statistics_from_dataframe(dataframe=score_test)

tfdv.visualize_statistics(
  lhs_statistics=train_stats, lhs_name='TRAIN_DATASET',
  rhs_statistics=test_stats, rhs_name='NEW_DATASET')
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ### Infer a schema
#
# Now let's use [`tfdv.infer_schema`](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/infer_schema) to create a schema for our data.  A schema defines constraints for the data that are relevant for ML. Example constraints include the data type of each feature, whether it's numerical or categorical, or the frequency of its presence in the data.  For categorical features the schema also defines the domain - the list of acceptable values.  Since writing a schema can be a tedious task, especially for datasets with lots of features, TFDV provides a method to generate an initial version of the schema based on the descriptive statistics.
#
# Getting the schema right is important because the rest of our production pipeline will be relying on the schema that TFDV generates to be correct.

# %% [markdown]
# #### Generating Schema
# Once statistics are generated, the next step is to generate a schema for our dataset. This schema will map each feature in the dataset to a type (float, bytes, etc.). Also define feature boundaries (min, max, distribution of values and missings, etc.).
#
# Link to infer schema
# https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/infer_schema
#
# With TFDV, we generate schema from statistics using

# %%
# Infers schema from the input statistics.
# TODO
schema = tfdv.infer_schema(statistics=stats)
print(schema)
# Out:
# feature {
#   name: "Graduated"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "Graduated"
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "Profession"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "Profession"
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "Work_Experience"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "Family_Size"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "Spending_Score"
#   type: BYTES
#   domain: "Spending_Score"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# string_domain {
#   name: "Graduated"
#   value: "No"
#   value: "Yes"
# }
# string_domain {
#   name: "Profession"
#   value: "Artist"
#   value: "Doctor"
#   value: "Engineer"
#   value: "Entertainment"
#   value: "Executive"
#   value: "Healthcare"
#   value: "Homemaker"
#   value: "Lawyer"
#   value: "Marketing"
# }
# string_domain {
#   name: "Spending_Score"
#   value: "Average"
#   value: "High"
#   value: "Low"
# }

# %% [markdown]
# The schema also provides documentation for the data, and so is useful when different developers work on the same data.  Let's use [`tfdv.display_schema`](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/display_schema) to display the inferred schema so that we can review it.

# %%
tfdv.display_schema(schema=schema)
# Out:
#                      Type  Presence Valency            Domain
# Feature name
# 'Graduated'        STRING  optional  single       'Graduated'
# 'Profession'       STRING  optional  single      'Profession'
# 'Work_Experience'   FLOAT  optional  single                 -
# 'Family_Size'       FLOAT  optional  single                 -
# 'Spending_Score'   STRING  required          'Spending_Score'
#                                                                                                                           Values
# Domain
# 'Graduated'                                                                                                          'No', 'Yes'
# 'Profession'      'Artist', 'Doctor', 'Engineer', 'Entertainment', 'Executive', 'Healthcare', 'Homemaker', 'Lawyer', 'Marketing'
# 'Spending_Score'                                                                                        'Average', 'High', 'Low'

# %% [markdown]
# #### TFDV provides a API to print a summary of each feature schema using
#
# In this visualization, the columns stand for:
#
# **Type** indicates the feature datatype.
#
# **Presence** indicates whether the feature must be present in 100% of examples (required) or not (optional).
#
# **Valency** indicates the number of values required per training example.
#
# **Domain and Values** indicates The feature domain and its values
#
# In the case of categorical features, single indicates that each training example must have exactly one category for the feature.

# %% [markdown]
# ### Updating the Schema
# As stated above, **Presence** indicates whether the feature must be present in 100% of examples (required) or not (optional).  Currently, all of our features except for our target label are shown as "optional". We need to make our features all required except for "Work Experience".  We will need to update the schema.

# %% [markdown]
# TFDV lets you update the schema according to your domain knowledge of the data if you are not satisfied by the auto-generated schema.  We will update three use cases:  Making a feature required, adding a value to a feature, and change a feature from a float to an integer.

# %% [markdown]
# #### Change optional features to required.

# %%
# Update Family_Size from FLOAT to Int
Graduated_feature = tfdv.get_feature(schema, 'Graduated')
Graduated_feature.presence.min_fraction = 1.0
Profession_feature = tfdv.get_feature(schema, 'Profession')
Profession_feature.presence.min_fraction = 1.0
Family_Size_feature = tfdv.get_feature(schema, 'Family_Size')
Family_Size_feature.presence.min_fraction = 1.0

# %%
tfdv.display_schema(schema)
# Out:
#                      Type  Presence Valency            Domain
# Feature name
# 'Graduated'        STRING  required  single       'Graduated'
# 'Profession'       STRING  required  single      'Profession'
# 'Work_Experience'   FLOAT  optional  single                 -
# 'Family_Size'       FLOAT  required  single                 -
# 'Spending_Score'   STRING  required          'Spending_Score'
#                                                                                                                           Values
# Domain
# 'Graduated'                                                                                                          'No', 'Yes'
# 'Profession'      'Artist', 'Doctor', 'Engineer', 'Entertainment', 'Executive', 'Healthcare', 'Homemaker', 'Lawyer', 'Marketing'
# 'Spending_Score'                                                                                        'Average', 'High', 'Low'

# %% [markdown]
# #### Update a feature with a new value

# %% [markdown]
# Let's add "self-employed" to the Profession feature

# %%
Profession_domain = tfdv.get_domain(schema, 'Profession')
Profession_domain.value.insert(0, 'Self-Employed')
Profession_domain.value
# [0 indicates I want 'Self-Employed to come first', if the number were 3, 
# it would be placed after the third value. ]
# Out:
# ['Self-Employed', 'Artist', 'Doctor', 'Engineer', 'Entertainment', 'Executive', 'Healthcare', 'Homemaker', 'Lawyer', 'Marketing']

# %% [markdown]
# #### Let's remove "Homemaker" from "Profession"

# %%
Profession_domain = tfdv.get_domain(schema, 'Profession')
Profession_domain.value.remove('Homemaker')

# %%
Profession_domain.value
# Out:
# ['Self-Employed', 'Artist', 'Doctor', 'Engineer', 'Entertainment', 'Executive', 'Healthcare', 'Lawyer', 'Marketing']

# %% [markdown]
# #### Change a feature from a float to an integer

# %%
# Update Family_Size to Int
size = tfdv.get_feature(schema, 'Family_Size')

# %%
size.type=2
tfdv.display_schema(schema)
# Out:
#                      Type  Presence Valency            Domain
# Feature name
# 'Graduated'        STRING  required  single       'Graduated'
# 'Profession'       STRING  required  single      'Profession'
# 'Work_Experience'   FLOAT  optional  single                 -
# 'Family_Size'         INT  required  single                 -
# 'Spending_Score'   STRING  required          'Spending_Score'
#                                                                                                                               Values
# Domain
# 'Graduated'                                                                                                              'No', 'Yes'
# 'Profession'      'Self-Employed', 'Artist', 'Doctor', 'Engineer', 'Entertainment', 'Executive', 'Healthcare', 'Lawyer', 'Marketing'
# 'Spending_Score'                                                                                            'Average', 'High', 'Low'

# %% [markdown]
# In the next lab, you compare two datasets and check for anomalies.

# %% [markdown]
# ## When to use TFDV
#
# It's easy to think of TFDV as only applying to the start of your training pipeline, as we did here, but in fact it has many uses. Here are a few more:
#
# * Validating new data for inference to make sure that we haven't suddenly started receiving bad features
# * Validating new data for inference to make sure that our model has trained on that part of the decision surface
# * Validating our data after we've transformed it and done feature engineering (probably using [TensorFlow Transform](https://www.tensorflow.org/tfx/guide/transform)) to make sure we haven't done something wrong

# %% [markdown]
# https://github.com/GoogleCloudPlatform/mlops-on-gcp/blob/master/examples/tfdv-structured-data/tfdv-covertype.ipynb
